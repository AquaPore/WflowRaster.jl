# %%
using ZipFile

Path = raw"D:\JOE\MAIN\MODELS\WFLOW\DATA\Timoleague\Sentinel\Sentinel_L2"

cd(Path)

	OutputPath = readdir(Path)

	for iTable ∈ OutputPath
		println(iTable)
		r = ZipFile.Reader(iTable)
	end
# Out:
# S2A_MSIL2A_20240305T114351_N0510_R123_T29UNT_20240305T151052.zip
# S2A_MSIL2A_20241011T114351_N0511_R123_T29UNT_20241011T151049.zip
# S2A_MSIL2A_20250102T115501_N0511_R023_T29UNT_20250102T144951.zip
# S2A_MSIL2A_20250710T114411_N0511_R123_T29UMT_20250710T151814.zip
# S2A_MSIL2A_20250812T115411_N0511_R023_T29UNT_20250812T161813.zip
# S2A_MSIL2A_20251117T114411_N0511_R123_T29UMT_20251117T151110.zip
# S2B_MSIL2A_20240212T115359_N0510_R023_T29UNT_20240212T130347.zip
# S2B_MSIL2A_20240422T115359_N0510_R023_T29UMT_20240422T154419.zip
# S2B_MSIL2A_20240519T114349_N0510_R123_T29UNT_20240519T135826.zip
# S2B_MSIL2A_20240601T115359_N0510_R023_T29UNT_20240601T141640.zip
# S2B_MSIL2A_20240830T115359_N0511_R023_T29UMT_20240830T155319.zip
# S2B_MSIL2A_20240916T114349_N0511_R123_T29UNT_20240916T171831.zip
# S2B_MSIL2A_20241125T114349_N0511_R123_T29UNT_20241125T125646.zip
# S2B_MSIL2A_20241208T115409_N0511_R023_T29UMT_20241208T153321.zip
# ...
