# %%
using DataFrames
import CairoMakie as Mke
# using NetCDF
using NCDatasets
using CairoMakie
# using Makie.Colors

# %%
Path = raw"D:\JOE\MAIN\MODELS\WFLOW\DATA\WflowExample\Data\input"
Path_Forcing = joinpath(Path,"forcing-moselle.nc")
isfile(Path_Forcing)
# Out:
# false

# %%
# All information of NCDataset
Output_NCDatasets = NCDatasets.NCDataset(Path_Forcing)
# Out:
# NetCDF error: Opening path D:\JOE\MAIN\MODELS\WFLOW\DATA\WflowExample\Data\input\forcing-moselle.nc: No such file or directory (NetCDF error code: 2)
#
#
#
# Stacktrace:
#
#  [1] nc_open(path::String, mode::UInt16)
#
#    @ NCDatasets C:\Users\jpollacco.local\.julia\packages\NCDatasets\WjwTE\src\netcdf_c.jl:276
#
#  [2] NCDataset(filename::String, mode::String; format::Symbol, share::Bool, diskless::Bool, persist::Bool, memory::Nothing, maskingvalue::Missing, attrib::Vector{Any})
#
#    @ NCDatasets C:\Users\jpollacco.local\.julia\packages\NCDatasets\WjwTE\src\dataset.jl:237
#
#  [3] NCDataset
#
#    @ C:\Users\jpollacco.local\.julia\packages\NCDatasets\WjwTE\src\dataset.jl:216 [inlined]
#
#  [4] NCDataset(filename::String)
#
#    @ NCDatasets C:\Users\jpollacco.local\.julia\packages\NCDatasets\WjwTE\src\dataset.jl:216
#
#  [5] top-level scope
#
#    @ d:\JOE\MAIN\MODELS\WFLOW\WflowRaster.jl\src\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W2sZmlsZQ==.jl:3

# %%
include("GeoPlot.jl")
geoPlot.HEATMAP_TIME(;Path=Path_Forcing, NameOutput="temp", Layer=1)
# Out:
# SystemError: opening file "d:\\JOE\\MAIN\\MODELS\\WFLOW\\WflowRaster.jl\\src\\GeoPlot.jl": No such file or directory
#
#
#
# Stacktrace:
#
#  [1] include(mapexpr::Function, mod::Module, _path::String)
#
#    @ Base .\Base.jl:307
#
#  [2] top-level scope
#
#    @ d:\JOE\MAIN\MODELS\WFLOW\WflowRaster.jl\src\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:1
