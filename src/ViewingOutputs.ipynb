# %%
# using DataFrames
# using GeoStats
# using GeoIO
# using Pkg
using NCDatasets, GLMakie
# using NetCDF
# using CairoMakie, ColorSchemes

# %%
# ================================================================
					# Plotting parameters
					ColourOption_No    = 1
					Linewidth          = 2
					height             = 400
					labelsize          = 20
					textcolor          = :blue
					textsize           = 20
					titlecolor         = :navyblue
					titlesize          = 18.0
					width              = height * 1.0
					xgridstyle         = :dash
					xgridvisible       = true
					xlabelSize         = 20
					xlabelpadding      = 5
					xminortickalign    = 1.0
					xminorticksvisible = true
					xtickalign         = 0.9 # 0 is inside and 1 is outside
					xticklabelrotation = π / 4.0
					xticksize          = 10
					xticksmirrored     = false
					xtickwidt          = 0.5
					xtrimspine         = false
					ygridstyle         = :dash
					ygridvisible       = false
					ylabelpadding      = xlabelpadding
					ylabelsize         = xlabelSize
					yminortickalign    = xminortickalign
					yminorticksvisible = true
					ytickalign         = xtickalign
					yticksize          = xticksize
					yticksmirrored     = false
					ytickwidt          = xtickwidt
					ytrimspine         = false

					Linewidth = 4
					xlabelSize = 30
					xticksize = 10
					xgridvisible = false
					Width = 800 # 800
					Height = 200
# Out:
# 200

# %%
Path = raw"D:\JOE\MAIN\MODELS\WFLOW\Wflow.jl\data\output"
Path_Output = joinpath(Path, "output_moselle.nc")
Path_Scalar = joinpath(Path, "output_scalar_moselle.nc")
Path_Outstates = joinpath(Path, "outstates-moselle.nc")

Path_Input = joinpath(Path, "forcing-moselle.nc")

Path_Input = Path_Output
# Out:
# "D:\\JOE\\MAIN\\MODELS\\WFLOW\\Wflow.jl\\data\\output\\output_moselle.nc"

# %%
# NetCDF.ncinfo(Path_Static)
# All information of NCDataset
Output_NCDatasets = NCDatasets.NCDataset(Path_Input)
# Out:
# NetCDF error: Opening path D:\JOE\MAIN\MODELS\WFLOW\Wflow.jl\data\output\output_moselle.nc: No such file or directory (NetCDF error code: 2)
#
#
#
# Stacktrace:
#
#  [1] nc_open(path::String, mode::UInt16)
#
#    @ NCDatasets C:\Users\jpollacco.local\.julia\packages\NCDatasets\WjwTE\src\netcdf_c.jl:276
#
#  [2] NCDataset(filename::String, mode::String; format::Symbol, share::Bool, diskless::Bool, persist::Bool, memory::Nothing, maskingvalue::Missing, attrib::Vector{Any})
#
#    @ NCDatasets C:\Users\jpollacco.local\.julia\packages\NCDatasets\WjwTE\src\dataset.jl:237
#
#  [3] NCDataset
#
#    @ C:\Users\jpollacco.local\.julia\packages\NCDatasets\WjwTE\src\dataset.jl:216 [inlined]
#
#  [4] NCDataset(filename::String)
#
#    @ NCDatasets C:\Users\jpollacco.local\.julia\packages\NCDatasets\WjwTE\src\dataset.jl:216
#
#  [5] top-level scope
#
#    @ d:\JOE\MAIN\MODELS\WFLOW\WflowRaster.jl\src\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W4sZmlsZQ==.jl:3

# %%
Keys = NCDatasets.keys(Output_NCDatasets)
Keys_Select = []

for iiKeys ∈ Keys
	Output = Output_NCDatasets[iiKeys]
	Dimensions = length(size(Output))
	println("$iiKeys   ; Dim=$Dimensions" )

	if Dimensions == 3
			push!(Keys_Select, String(iiKeys))
	end # Dimensions == 2
end # for iiKeys ∈ Keys

Keys_Select = String.(Keys_Select)
println()
@show Keys_Select
# Out:
# UndefVarError: `Output_NCDatasets` not defined in `Main`
#
# Suggestion: add an appropriate import or assignment. This global was declared but not assigned.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ d:\JOE\MAIN\MODELS\WFLOW\WflowRaster.jl\src\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W5sZmlsZQ==.jl:1

# %%
using GLMakie
GLMakie.activate!
Makie.inline!(false)  # Make sure to inline plots into Documenter output!


function HEATMAP_TIME(;Path=Path, NameOutput="q_land", Layer=1)
	Output_NCDatasets = NCDatasets.NCDataset(Path)

	Data = Output_NCDatasets[NameOutput]

	Data = Array(Data)

	Dimensions = length(size(Data))

	if Dimensions == 3
		N_Lon = size(Data)[1]
		N_Lat  = size(Data)[2]
		N_Time  = size(Data)[3]

	elseif Dimensions == 4
		N_Lon = size(Data)[1]
		N_Lat  = size(Data)[2]
		N_Time  = size(Data)[4]
	end

	Pmin, Pmax = extrema(x for x ∈ skipmissing(Data) if !isnan(x))
	@show Pmin Pmax

	function DATA_3D_2_2D(Data; iTime=iTime, Dimensions=Dimensions, Layer=Layer)
		if Dimensions == 4
			return Data[:,:, Layer, iTime]
		elseif Dimensions == 3
			return Data[:,:, iTime]
		end
	end


	Fig = Figure(size=(Width, Height * 4.0))

	Ax_1 = Axis(Fig[1, 1], title=NameOutput, xlabelsize=xlabelSize, ylabelsize=xlabelSize, xticksize=xticksize, xgridvisible=xgridvisible, ygridvisible=xgridvisible)

	sg = SliderGrid(Fig[2, 1],
	(label="iTime", range=1:1:N_Time, startvalue=1),
	width=550, tellheight=true)

	iTime = sg.sliders[1].value

	Data_Time = lift((iTime) -> DATA_3D_2_2D(Data; iTime=iTime, Dimensions), iTime)


	Data_Plot = heatmap!(Ax_1, 1:N_Lon, 1:N_Lat, Data_Time, colorrange=(Pmin, Pmax), colormap =:hawaii50)

	Colorbar(Fig[1, 2], Data_Plot; label=NameOutput, width=20, ticks = Pmin:(Pmax-Pmin)/5:Pmax)

	Fig
end
# Out:
# HEATMAP_TIME (generic function with 1 method)

# %%
# HEATMAP_TIME(;Path=Path_Input, NameOutput="h_av_land", Layer=1)
HEATMAP_TIME(;Path=Path_Input, NameOutput="ustorelayerdepth", Layer=1)
# HEATMAP_TIME(;Path=Path_Input, NameOutput="q_av_river", Layer=1)

# HEATMAP_TIME(;Path=Path_Output, NameOutput="ustorelayerdepth")
# Out:
# NetCDF error: Opening path D:\JOE\MAIN\MODELS\WFLOW\Wflow.jl\data\output\output_moselle.nc: No such file or directory (NetCDF error code: 2)
#
#
#
# Stacktrace:
#
#  [1] nc_open(path::String, mode::UInt16)
#
#    @ NCDatasets C:\Users\jpollacco.local\.julia\packages\NCDatasets\WjwTE\src\netcdf_c.jl:276
#
#  [2] NCDataset(filename::String, mode::String; format::Symbol, share::Bool, diskless::Bool, persist::Bool, memory::Nothing, maskingvalue::Missing, attrib::Vector{Any})
#
#    @ NCDatasets C:\Users\jpollacco.local\.julia\packages\NCDatasets\WjwTE\src\dataset.jl:237
#
#  [3] NCDataset (repeats 2 times)
#
#    @ C:\Users\jpollacco.local\.julia\packages\NCDatasets\WjwTE\src\dataset.jl:216 [inlined]
#
#  [4] HEATMAP_TIME(; Path::String, NameOutput::String, Layer::Int64)
#
#    @ Main d:\JOE\MAIN\MODELS\WFLOW\WflowRaster.jl\src\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W6sZmlsZQ==.jl:7
#
#  [5] top-level scope
#
#    @ d:\JOE\MAIN\MODELS\WFLOW\WflowRaster.jl\src\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X10sZmlsZQ==.jl:2
